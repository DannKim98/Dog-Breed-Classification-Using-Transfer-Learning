# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
MyAlexNet_train_loss_list = pd.read_csv('MyAlexNet/MyAlexNet_train_loss_list.csv')
MyAlexNet_test_loss_list = pd.read_csv('MyAlexNet/MyAlexNet_test_loss_list.csv')
MyAlexNet_test_accuracy_list = pd.read_csv('MyAlexNet/MyAlexNet_test_accuracy_list.csv')
MyAlexNet_train_loss_list = MyAlexNet_train_loss_list.values
MyAlexNet_test_loss_list = MyAlexNet_test_loss_list.values
MyAlexNet_test_accuracy_list = MyAlexNet_test_accuracy_list.values

# %%
MyVGG16_train_loss_list = pd.read_csv('MyVGG16/MyVGG16_train_loss_list.csv')
MyVGG16_test_loss_list = pd.read_csv('MyVGG16/MyVGG16_test_loss_list.csv')
MyVGG16_test_accuracy_list = pd.read_csv('MyVGG16/MyVGG16_test_accuracy_list.csv')
MyVGG16_train_loss_list = MyVGG16_train_loss_list.values
MyVGG16_test_loss_list = MyVGG16_test_loss_list.values
MyVGG16_test_accuracy_list = MyVGG16_test_accuracy_list.values

# %%
MySimpleNetAdam_train_loss_list = pd.read_csv('MySimpleNetAdam/MySimpleNetAdam_train_loss_list.csv')
MySimpleNetAdam_test_loss_list = pd.read_csv('MySimpleNetAdam/MySimpleNetAdam_test_loss_list.csv')
MySimpleNetAdam_test_accuracy_list = pd.read_csv('MySimpleNetAdam/MySimpleNetAdam_test_accuracy_list.csv')
MySimpleNetAdam_train_loss_list = MySimpleNetAdam_train_loss_list.values
MySimpleNetAdam_test_loss_list = MySimpleNetAdam_test_loss_list.values
MySimpleNetAdam_test_accuracy_list = MySimpleNetAdam_test_accuracy_list.values

# %%
MySimpleNetSGD_train_loss_list = pd.read_csv('MySimpleNetSGD/MySimpleNetSGD_train_loss_list.csv')
MySimpleNetSGD_test_loss_list = pd.read_csv('MySimpleNetSGD/MySimpleNetSGD_test_loss_list.csv')
MySimpleNetSGD_test_accuracy_list = pd.read_csv('MySimpleNetSGD/MySimpleNetSGD_test_accuracy_list.csv')
MySimpleNetSGD_train_loss_list = MySimpleNetSGD_train_loss_list.values
MySimpleNetSGD_test_loss_list = MySimpleNetSGD_test_loss_list.values
MySimpleNetSGD_test_accuracy_list = MySimpleNetSGD_test_accuracy_list.values

# %%
MySimpleNet1Adam_train_loss_list = pd.read_csv('MySimpleNet1Adam/MySimpleNet1Adam_train_loss_list.csv')
MySimpleNet1Adam_test_loss_list = pd.read_csv('MySimpleNet1Adam/MySimpleNet1Adam_test_loss_list.csv')
MySimpleNet1Adam_test_accuracy_list = pd.read_csv('MySimpleNet1Adam/MySimpleNet1Adam_test_accuracy_list.csv')
MySimpleNet1Adam_train_loss_list = MySimpleNet1Adam_train_loss_list.values
MySimpleNet1Adam_test_loss_list = MySimpleNet1Adam_test_loss_list.values
MySimpleNet1Adam_test_accuracy_list = MySimpleNet1Adam_test_accuracy_list.values

# %%
MySimpleNet2Adam_train_loss_list = pd.read_csv('MySimpleNet2Adam/MySimpleNet2Adam_train_loss_list.csv')
MySimpleNet2Adam_test_loss_list = pd.read_csv('MySimpleNet2Adam/MySimpleNet2Adam_test_loss_list.csv')
MySimpleNet2Adam_test_accuracy_list = pd.read_csv('MySimpleNet2Adam/MySimpleNet2Adam_test_accuracy_list.csv')
MySimpleNet2Adam_train_loss_list = MySimpleNet2Adam_train_loss_list.values
MySimpleNet2Adam_test_loss_list = MySimpleNet2Adam_test_loss_list.values
MySimpleNet2Adam_test_accuracy_list = MySimpleNet2Adam_test_accuracy_list.values

# %%
VGG16_25ep_train_loss_list = pd.read_csv('VGG16_25ep/VGG16_25ep_train_loss_list.csv')
VGG16_25ep_test_loss_list = pd.read_csv('VGG16_25ep/VGG16_25ep_test_loss_list.csv')
VGG16_25ep_test_accuracy_list = pd.read_csv('VGG16_25ep/VGG16_25ep_test_accuracy_list.csv')
VGG16_25ep_train_loss_list = VGG16_25ep_train_loss_list.values
VGG16_25ep_test_loss_list = VGG16_25ep_test_loss_list.values
VGG16_25ep_test_accuracy_list = VGG16_25ep_test_accuracy_list.values

# %%
ResNet30_train_loss_list = pd.read_csv('ResNet30/ResNet_train_loss_list.csv')
ResNet30_test_loss_list = pd.read_csv('ResNet30/ResNet_test_loss_list.csv')
ResNet30_test_accuracy_list = pd.read_csv('ResNet30/ResNet_test_accuracy_list.csv')
ResNet30_train_loss_list = ResNet30_train_loss_list.values
ResNet30_test_loss_list = ResNet30_test_loss_list.values
ResNet30_test_accuracy_list = ResNet30_test_accuracy_list.values

# %%
ResNet50_25ep_train_loss_list = pd.read_csv('ResNet50_25ep/ResNet50_25ep_train_loss_list.csv')
ResNet50_25ep_test_loss_list = pd.read_csv('ResNet50_25ep/ResNet50_25ep_test_loss_list.csv')
ResNet50_25ep_test_accuracy_list = pd.read_csv('ResNet50_25ep/ResNet50_25ep_test_accuracy_list.csv')
ResNet50_25ep_train_loss_list = ResNet50_25ep_train_loss_list.values
ResNet50_25ep_test_loss_list = ResNet50_25ep_test_loss_list.values
ResNet50_25ep_test_accuracy_list = ResNet50_25ep_test_accuracy_list.values

# %%
ResNet152_25ep_train_loss_list = pd.read_csv('ResNet152_25ep/ResNet152_25ep_train_loss_list.csv')
ResNet152_25ep_test_loss_list = pd.read_csv('ResNet152_25ep/ResNet152_25ep_test_loss_list.csv')
ResNet152_25ep_test_accuracy_list = pd.read_csv('ResNet152_25ep/ResNet152_25ep_test_accuracy_list.csv')
ResNet152_25ep_train_loss_list = ResNet152_25ep_train_loss_list.values
ResNet152_25ep_test_loss_list = ResNet152_25ep_test_loss_list.values
ResNet152_25ep_test_accuracy_list = ResNet152_25ep_test_accuracy_list.values

# %%
ResNet152_10ep64batch_train_loss_list = pd.read_csv('ResNet152_10ep64batch/ResNet152_10ep64batch_train_loss_list.csv')
ResNet152_10ep64batch_test_loss_list = pd.read_csv('ResNet152_10ep64batch/ResNet152_10ep64batch_test_loss_list.csv')
ResNet152_10ep64batch_test_accuracy_list = pd.read_csv('ResNet152_10ep64batch/ResNet152_10ep64batch_test_accuracy_list.csv')
ResNet152_10ep64batch_train_loss_list = ResNet152_10ep64batch_train_loss_list.values
ResNet152_10ep64batch_test_loss_list = ResNet152_10ep64batch_test_loss_list.values
ResNet152_10ep64batch_test_accuracy_list = ResNet152_10ep64batch_test_accuracy_list.values

# %%
ResNet152_10ep64batchRMS_train_loss_list = pd.read_csv('ResNet152_10ep64batchRMS/ResNet152_10ep64batchRMS_train_loss_list.csv')
ResNet152_10ep64batchRMS_test_loss_list = pd.read_csv('ResNet152_10ep64batchRMS/ResNet152_10ep64batchRMS_test_loss_list.csv')
ResNet152_10ep64batchRMS_test_accuracy_list = pd.read_csv('ResNet152_10ep64batchRMS/ResNet152_10ep64batchRMS_test_accuracy_list.csv')
ResNet152_10ep64batchRMS_train_loss_list = ResNet152_10ep64batchRMS_train_loss_list.values
ResNet152_10ep64batchRMS_test_loss_list = ResNet152_10ep64batchRMS_test_loss_list.values
ResNet152_10ep64batchRMS_test_accuracy_list = ResNet152_10ep64batchRMS_test_accuracy_list.values

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(MyAlexNet_test_loss_list)), MyAlexNet_test_loss_list, 'r', label='validation')
plt.plot(range(len(MyAlexNet_train_loss_list)), MyAlexNet_train_loss_list, 'b', label='train')

plt.title('MyAlexNet Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', MyAlexNet_test_accuracy_list[29][0],'%')
# Out:
# Accuracy 5.073649754500818 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(MyVGG16_test_loss_list)), MyVGG16_test_loss_list, 'r', label='validation')
plt.plot(range(len(MyVGG16_train_loss_list)), MyVGG16_train_loss_list, 'b', label='train')

plt.title('MyVGG16 Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', MyVGG16_test_accuracy_list[29][0],'%')
# Out:
# Accuracy 0.9819967266775774 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(MySimpleNetSGD_test_loss_list)), MySimpleNetSGD_test_loss_list, 'r', label='validation')
plt.plot(range(len(MySimpleNetSGD_train_loss_list)), MySimpleNetSGD_train_loss_list, 'b', label='train')

plt.title('MySimpleNetSGD Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', MySimpleNetSGD_test_accuracy_list[29][0],'%')
# Out:
# Accuracy 0.7364975450081833 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(MySimpleNetAdam_test_loss_list)), MySimpleNetAdam_test_loss_list, 'r', label='validation')
plt.plot(range(len(MySimpleNetAdam_train_loss_list)), MySimpleNetAdam_train_loss_list, 'b', label='train')

plt.title('MySimpleNetAdam Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', MySimpleNetAdam_test_accuracy_list[29][0],'%')
# Out:
# Accuracy 8.01963993453355 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(MySimpleNet1Adam_test_loss_list)), MySimpleNet1Adam_test_loss_list, 'r', label='validation')
plt.plot(range(len(MySimpleNet1Adam_train_loss_list)), MySimpleNet1Adam_train_loss_list, 'b', label='train')

plt.title('MySimpleNet1Adam Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', MySimpleNet1Adam_test_accuracy_list[29][0],'%')
# Out:
# Accuracy 7.528641571194763 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(MySimpleNet2Adam_test_loss_list)), MySimpleNet2Adam_test_loss_list, 'r', label='validation')
plt.plot(range(len(MySimpleNet2Adam_train_loss_list)), MySimpleNet2Adam_train_loss_list, 'b', label='train')

plt.title('MySimpleNet2Adam Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', MySimpleNet2Adam_test_accuracy_list[29][0],'%')
# Out:
# Accuracy 8.919803600654662 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(VGG16_25ep_test_loss_list)), VGG16_25ep_test_loss_list, 'r', label='validation')
plt.plot(range(len(VGG16_25ep_train_loss_list)), VGG16_25ep_train_loss_list, 'b', label='train')

plt.title('VGG16_25ep Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', VGG16_25ep_test_accuracy_list[24][0],'%')
# Out:
# Accuracy 52.045826513911614 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(ResNet30_test_loss_list[:25])), ResNet30_test_loss_list[:25], 'r', label='validation')
plt.plot(range(len(ResNet30_train_loss_list[:25])), ResNet30_train_loss_list[:25], 'b', label='train')

plt.title('ResNet18_25ep Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', ResNet30_test_accuracy_list[24][0],'%')
# Out:
# Accuracy 51.47299509001637 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(ResNet50_25ep_test_loss_list)), ResNet50_25ep_test_loss_list, 'r', label='validation')
plt.plot(range(len(ResNet50_25ep_train_loss_list)), ResNet50_25ep_train_loss_list, 'b', label='train')

plt.title('ResNet50_25ep Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', ResNet50_25ep_test_accuracy_list[24][0],'%')
# Out:
# Accuracy 63.58428805237316 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(ResNet152_25ep_test_loss_list)), ResNet152_25ep_test_loss_list, 'r', label='validation')
plt.plot(range(len(ResNet152_25ep_train_loss_list)), ResNet152_25ep_train_loss_list, 'b', label='train')

plt.title('ResNet152_25ep Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', ResNet152_25ep_test_accuracy_list[24][0],'%')
# Out:
# Accuracy 66.20294599018001 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(ResNet152_10ep64batch_test_loss_list)), ResNet152_10ep64batch_test_loss_list, 'r', label='validation')
plt.plot(range(len(ResNet152_10ep64batch_train_loss_list)), ResNet152_10ep64batch_train_loss_list, 'b', label='train')

plt.title('ResNet152_10ep64batch Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', ResNet152_10ep64batch_test_accuracy_list[9][0],'%')
# Out:
# Accuracy 62.92962356792143 %

# %%
plt.rcParams['figure.figsize'] = (9,6)
plt.plot(range(len(ResNet152_10ep64batchRMS_test_loss_list)), ResNet152_10ep64batchRMS_test_loss_list, 'r', label='validation')
plt.plot(range(len(ResNet152_10ep64batchRMS_train_loss_list)), ResNet152_10ep64batchRMS_train_loss_list, 'b', label='train')

plt.title('ResNet152_10ep64batchRMSprop Loss vs Epoch')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
print('Accuracy', ResNet152_10ep64batchRMS_test_accuracy_list[8][0],'%')
# Out:
# Accuracy 83.22422258592471 %
